# %% [markdown]
# <a href="https://colab.research.google.com/github/allnlk/NM/blob/main/%D0%A4%D0%86%D0%A2_2_10_%D0%9A%D1%83%D0%B1%D1%80%D0%B0%D0%BA_%D0%90_%D0%92%D0%B0%D1%80%D1%96%D0%B0%D0%BD%D1%82_13_%22%D0%9BP_12_%D0%A7%D0%B8%D1%81%D0%B5%D0%BB%D1%8C%D0%BD%D0%B5_%D1%96%D0%BD%D1%82%D0%B5%D0%B3%D1%80%D1%83%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ЛР 12 "Чисельне інтегрування". ФІТ 2-10. Кубрак А. Варіант 13.

# %% [markdown]
# Завдання 3. Визначити інтеграм методом трапецій

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Обчислення інтегралу методом трапецій

from scipy import integrate
import numpy as np

# Задаємо функцію, яку необхідно інтегрувати
def f(x):
    #return 1 / sqrt(x^2 + 1.2)
    return 1 / np.sqrt(x**2 + 1.2)

# Задаємо межі інтегрування та початкову кількість розбиттів
a, b, n = 1.2, 2, 10

# Обчислюємо значення інтегралу методом трапецій
def trapezoidal_rule(f, a, b, n):
    h = (b - a) / n
    sum = 0.5 * (f(a) + f(b))
    x = a

    for i in range(1, n):
        x += h
        sum += f(x)

    integral = h * sum

    return integral

# Виводимо результат методу трапецій
integral = trapezoidal_rule(f, a, b, n)
print("Trapetzia method result:", round(integral, 5))

# Перевірка за допомогою вбудованої функції
v, err = integrate.quad(f, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Trapetzia method result: 0.41565
# Check with SciPy quad method: 0.41559

# %% [markdown]
# Завдання 1. Метод прямокутників (правих, лівих і середніх)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Обчислення інтеграла методом прямокутників
from scipy import integrate
import numpy as np

a, b, n = 0.4, 1.2, 10

h = (b - a) / n  # Крок

def f1(x):
    #return 1 / sqrt(0.5x + 2)
    return 1 / np.sqrt(0.5 * x + 2)

# Метод лівих прямокутників
def left_rec(f1, a, b):
    sum = 0
    for i in range(0, n):
        sum += f1(a + i * h)
    return sum * h

print("Left rectangle:", round(left_rec(f1, a, b), 5))

# Метод правих прямокутників
def right_rec(f1, a, b):
    sum = 0
    for i in range(1, n+1):
        sum += f1(a + i * h)
    return sum * h

print("Right rectangle:", round(right_rec(f1, a, b), 5))

# Метод середніх прямокутників
def aver_rec(f1, a, b):
    sum = 0
    for i in range(0, n):
        sum += f1(a + (i + 0.5) * h)
    return sum * h

print("Average rectangle:", round(aver_rec(f1, a, b), 5))

# Перевірка за допомогою функції scipy
v, err = integrate.quad(f1, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Left rectangle: 0.51902
# Right rectangle: 0.5147
# Average rectangle: 0.51684
# Check with SciPy quad method: 0.51685

# %% [markdown]
# Завдання 2. Метод Симпсона

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Обчислення інтеграла методом Симпсона
from scipy import integrate
import numpy as np

# Задаємо функцію, яку необхідно інтегрувати
def f(x):
    return x**2 * np.log10(x)

# Задаємо межі інтегрування та початкову кількість розбиттів
a, b, n = 1.4, 3, 8

h = (b - a) / n

# Обчислюємо значення інтегралу методом Симпсона
def simpson_rule(f, a, b, n):
    integr = f(a) + f(b)
    for i in range(1,n):
        k = a + i*h
        if i%2 == 0:
            integr += 2 * f(k)
        else:
            integr += 4 * f(k)
    integr *= h/3
    return integr


# Виводимо результат
print("Simpsone method:", round(simpson_rule(f, a, b, n), 3))

v,err = integrate.quad(f,a,b)#Перевірка
print("Check for the simpsone method= ",round(v, 3))
# Out:
# Simpsone method: 2.99
# Check for the simpsone method=  2.99
