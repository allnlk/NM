# %% [markdown]
# <a href="https://colab.research.google.com/github/allnlk/NM/blob/main/%D0%9A%D1%83%D0%B1%D1%80%D0%B0%D0%BA_%D0%90_2_10_%D0%92%D0%B0%D1%80%D1%96%D0%B0%D0%BD%D1%82_13_%22%D0%9B%D0%A0_13_%D0%A7%D0%9C_%D0%A0%D0%BE%D0%B7%D0%B2'%D1%8F%D0%B7%D0%B0%D0%BD%D0%BD%D1%8F_%D0%B4%D0%B8%D1%84_%D1%80%D1%96%D0%B2%D0%BD%D1%8F%D0%BD%D1%8C_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторна робота 13.
# Кубрак А. 2-10. Варіант 13

# %% [markdown]
# ![Знімок екрана (164).png](data:image/png;base64,...)
# ![Знімок екрана (165).png](data:image/png;base64,...)

# %% [markdown]
# #Метод Ейлера

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x + np.sin(y / np.sqrt(10))

# Вводимо параметри (ліва, права межі відрізку, крок, початкова умова)
a, b, h, y0 = 0.6, 1.6, 0.2, 0.8

# Перевірка вхідних параметрів
if h <= 0:
    print("Крок h повинен бути позитивним.")
    exit()
if a >= b:
    print("Права межа b повинна бути більшою за ліву межу a.")
    exit()

n = int((b - a) / h) # кількість кроків

x = np.array([a + i*h for i in range(n + 1)]) # задаємо x генератором списків

y = np.empty(n + 1)
y[0] = y0

for i in range(n):
    y[i + 1] = y[i] + f(x[i], y[i]) * h

y_rounded = np.round(y, 4)
print("x =", x, "\ny =", y_rounded)

plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера")
plt.legend(["точки", "x + sin(y / sqrt(10))"])
plt.grid()
plt.show()
# Out:
# x = [0.6 0.8 1.  1.2 1.4 1.6]
# y = [0.8    0.9701 1.1905 1.464  1.7933 2.1807]

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x + np.cos(y / 2.25)

# Вводимо параметри (ліва, права межі відрізку, крок, початкова умова)
a, b, h, y0 = 1.4, 2.4, 0.2, 2.2

# Перевірка вхідних параметрів
if h <= 0:
    print("Крок h повинен бути позитивним.")
    exit()
if a >= b:
    print("Права межа b повинна бути більшою за ліву межу a.")
    exit()

n = int((b - a) / h) # кількість кроків

x = np.array([a + i*h for i in range(n + 1)]) # задаємо x генератором списків

y = np.empty(n + 1)
y[0] = y0

for i in range(n):
    y[i + 1] = y[i] + f(x[i], y[i]) * h

y_rounded = np.round(y, 4)
print("x =", x, "\ny =", y_rounded)

plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера")
plt.legend(["точки", "x + cos(y / 2.25)"])
plt.grid()
plt.show()
# Out:
# x = [1.4 1.6 1.8 2.  2.2 2.4]
# y = [2.2    2.5918 2.9931 3.4008 3.8126 4.2279]

# %%
#Додати перевірку odeint для першого завдання
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(y, x):
    return x + np.sin(y / np.sqrt(10))

y0 = 0.8


x = np.arange(0.6, 1.6 + 0.0001, 0.2)

# Розв'язання ODE
y = odeint(model, y0, x)

# Виведення результатів
print('x =', x)
print('y =', y.flatten())

# Побудова графіка результатів
plt.plot(x, y, marker='o')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.title("Розв’язання диф.рівняння (а)")
plt.grid()
plt.show()
# Out:
# x = [0.6 0.8 1.  1.2 1.4 1.6]
# y = [0.8        0.99575535 1.24484775 1.55007523 1.91389462 2.33810717]

# %%
#додати перевірку solve_ivp для перешого завдання
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(x, y):
    return x + np.sin(y / np.sqrt(10))

y0 = [0.8]

x = np.linspace(0.6, 1.6, 6)

# Розв'язання ODE методом solve_ivp
sol = solve_ivp(model, [0.6, 1.6], y0, t_eval=x)

# Виведення результатів
print("x =", sol.t)
print("y =", sol.y[0])

# Побудова графіка результатів
plt.plot(sol.t, sol.y[0], marker='o')
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Розв’язання диф. рівняння(а)")
plt.grid()
plt.show()
# Out:
# x = [0.6 0.8 1.  1.2 1.4 1.6]
# y = [0.8        0.99573366 1.24480391 1.55009839 1.91395494 2.33812596]

# %% [markdown]
# #Метод Ейлера-Коші

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x + np.sin(y / np.sqrt(10))

a = 0.6  # ліва межа відрізку
b = 1.6  # права межа відрізку
h = 0.2  # крок
y0 = 0.8  # початкова умова
n = int((b - a) / h)  # кількість кроків

# Генерація x, враховуючи останнє значення
x = np.linspace(a, b, n + 1)  # Задати x з включенням b

y = np.empty(n + 1)
y[0] = y0

# Метод Ейлера-Коші
for i in range(n):
    # Використовується середнє значення для нахилу
    y[i + 1] = y[i] + (f(x[i], y[i]) + f(x[i + 1], y[i] + h * f(x[i], y[i]))) * h / 2

y_rounded = np.round(y, 4)

print("x =", x, "\ny =", y_rounded)

# Візуалізація
plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера-Коші")
plt.legend(["точки", "x + sin(y/sqrt(10))"])
plt.grid()
plt.show()
# Out:
# x = [0.6 0.8 1.  1.2 1.4 1.6]
# y = [0.8    0.9952 1.2437 1.5483 1.9114 2.3348]

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x + np.sin(y / np.sqrt(10))

a = 1.4  # ліва межа відрізку
b = 2.4  # права межа відрізку
h = 0.2  # крок
y0 = 2.2  # початкова умова
n = int((b - a) / h)  # кількість кроків

# Генерація x, враховуючи останнє значення
x = np.linspace(a, b, n + 1)  # Задати x з включенням b

y = np.empty(n + 1)
y[0] = y0

# Метод Ейлера-Коші
for i in range(n):
    # Використовується середнє значення для нахилу
    y[i + 1] = y[i] + (f(x[i], y[i]) + f(x[i + 1], y[i] + h * f(x[i], y[i]))) * h / 2

y_rounded = np.round(y, 4)

print("x =", x, "\ny =", y_rounded)

# Візуалізація
plt.plot(x, y, "o", x, y, "red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Метод Ейлера-Коші")
plt.legend(["точки", "x + cos(y/2.25)"])
plt.grid()
plt.show()
# Out:
# x = [1.4 1.6 1.8 2.  2.2 2.4]
# y = [2.2    2.6375 3.1348 3.69   4.2996 4.9574]

# %% [markdown]
# #Розв’язок диф. Рівняння за допомогою scipy.integrate import odeint

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(y, x):
    return x + np.sin(y / np.sqrt(10))

# Початкова умова
y0 = 0.8

# Значення x
x = np.array([0.6 + i * 0.2 for i in range(0, 6)])

# Розв'язання ODE
y = odeint(model, y0, x)

# Виведення результатів
print('x=', x)
print('y=', y.flatten())  # Перетворення в одновимірний масив для виводу

# Побудова графіка результатів
plt.plot(x, y, marker='o')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Розв’язання диф. рівняння')
plt.grid()
plt.show()
# Out:
# x= [0.6 0.8 1.  1.2 1.4 1.6]
# y= [0.8        0.99575535 1.24484775 1.55007523 1.91389462 2.33810717]

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(y, x):
    return x + np.cos(y / 2.25)

# Початкова умова
y0 = 2.2

# Значення x
x = np.array([1.4 + i * 0.2 for i in range(0, 6)])

# Розв'язання ODE
y = odeint(model, y0, x)

# Виведення результатів
print('x=', x)
print('y=', y.flatten())  # Перетворення в одновимірний масив для виводу

# Побудова графіка результатів
plt.plot(x, y, marker='o')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Розв’язання диф. рівняння')
plt.grid()
plt.show()
# Out:
# x= [1.4 1.6 1.8 2.  2.2 2.4]
# y= [2.2        2.59667268 3.0008506  3.40997003 3.82271343 4.23902157]

# %% [markdown]
# #Використання scipy.integrate.solve_ivp
# Функція solve_ivp є більш сучасним і гнучким способом розв'язання ODE, ніж odeint. Вона також дозволяє використовувати різні методи інтегрування.

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(x, y):
    return x + np.sin(y / np.sqrt(10))

# Початкова умова
y0 = [0.8]  # Потрібно передати як список

# Значення x
x = np.linspace(0.6, 1.6, 6)

# Розв'язання ODE
sol = solve_ivp(model, [0.6, 1.6], y0, t_eval=x)

# Виведення результатів
print('x=', sol.t)
print('y=', sol.y[0])

# Побудова графіка результатів
plt.plot(sol.t, sol.y[0], marker='o')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Розв’язання диф. рівняння')
plt.grid()
plt.show()
# Out:
# x= [0.6 0.8 1.  1.2 1.4 1.6]
# y= [0.8        0.99573366 1.24480391 1.55009839 1.91395494 2.33812596]

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Функція, що повертає dy/dx
def model(x, y):
    return x + np.cos(y / 2.25)

# Початкова умова
y0 = [2.2]  # Потрібно передати як список

# Значення x
x = np.linspace(1.4, 2.4, 6)

# Розв'язання ODE
sol = solve_ivp(model, [1.4, 2.4], y0, t_eval=x)

# Виведення результатів
print('x=', sol.t)
print('y=', sol.y[0])

# Побудова графіка результатів
plt.plot(sol.t, sol.y[0], marker='o')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.title('Розв’язання диф. рівняння')
plt.grid()
plt.show()
# Out:
# x= [1.4 1.6 1.8 2.  2.2 2.4]
# y= [2.2        2.596676   3.00086246 3.40998268 3.82271739 4.23901424]
